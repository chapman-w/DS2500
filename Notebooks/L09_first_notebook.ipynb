# %%
print("hello DS2500")
foo(8)
# Out:
# hello DS2500
# 64

# %%
lst = [i for i in range(5)]
lst
# Out:
# [0, 1, 2, 3, 4]

# %%
def foo(num):
    return num ** 2

# %%
foo(4)
# Out:
# 16

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(lst)

# %% [markdown]
# This is a sentence in my notebook. I am using this to explain to the reader what I am doing.

# %% [markdown]
# #### Thanks for checking out my notebook!
