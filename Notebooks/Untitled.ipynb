# %%
import pandas as pd

# %%
pd.read_csv('../classwork/data/test_stats.csv')
# Out:
#       last_name, first_name  player_id  year   pa  k_percent  bb_percent  \
# 0             Duran, Jarren     680776  2024  735       21.8         7.3
# 1    Guerrero Jr., Vladimir     665489  2024  697       13.8        10.3
# 2           Witt Jr., Bobby     677951  2024  709       15.0         8.0
# 3             Ramírez, José     608070  2024  682       12.0         7.9
# 4         McCutchen, Andrew     457705  2024  515       25.8        11.3
# ..                      ...        ...   ...  ...        ...         ...
# 124            Diaz, Yainer     673237  2024  619       17.3         3.9
# 125       Lindor, Francisco     596019  2024  689       18.4         8.1
# 126           Bregman, Alex     608324  2024  634       13.6         6.9
# 127            Peña, Jeremy     665161  2024  650       17.1         3.8
# 128            Altuve, Jose     514888  2024  682       17.4         6.9
#
#       woba  xwoba  sweet_spot_percent  barrel_batted_rate  hard_hit_percent  \
# ...
